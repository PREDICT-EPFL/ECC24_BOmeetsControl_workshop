# %% [markdown]
# # Bayesian Optimization Tutorial: Controller Tuning for Classical Control Task using the Ax package.
# **By Wenjie Xu**
#
# Throughout this tutorial, you will see blocks of code. In some of the places, they contain a block of code like:
# ```python
# ## Edit here.
# ...
# ## Stop editing here.
# ```
#
# These indicate the part of code with different parameters, so that you can experiment with changing parameters. Remember that these hyperparameters may have far-reaching effects on the whole tutorial!
#
# ### Introduction
# For this tutorial, we will attempt to tune a PID controller for the classical acrobot.
#
# The two main components of Bayesian optimization are:
# 1. Defining the reward in this case, which is to be maximized.
# 2. An "acqusition function" $q(x)$ that informs us of the value in samping the new point $x$ for optimization purpose.

# %%
import gym
import numpy as np
from pyvirtualdisplay import Display
import time
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
from matplotlib.animation import FuncAnimation
from IPython.display import Video, display
from render import show_video

# %% [markdown]
# # The goal is to swing the free end of the outer-link to reach the target height controlled by a PID controller as quickly as possible.

# %%
display(Video('./render_videos/acrobot_play.mp4', embed=True))
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# import Ax related packages
from ax.service.ax_client import AxClient, ObjectiveProperties
from ax.utils.notebook.plotting import init_notebook_plotting, render

# %%
# construct an Ax client to interact with the ax packages
controller_tuner_client = AxClient()
# Out:
# [INFO 06-15 17:11:39] ax.service.ax_client: Starting optimization with verbose logging. To disable logging, set the `verbose_logging` argument to `False`. Note that float values in the logs are rounded to 6 decimal points.

# %%
# create an experiment 
# Create an experiment with required arguments: name, parameters, and objective_name.
controller_tuner_client.create_experiment(
    name="tune_acrobot",  # The name of the experiment.
    parameters=[
        {
            "name": "kp",  # The name of the parameter.
            "type": "range",  # The type of the parameter ("range", "choice" or "fixed").
            "bounds": [-5.0, 5.0],  # The bounds for range parameters. 
            # "values" The possible values for choice parameters .
            # "value" The fixed value for fixed parameters.
            "value_type": "float",  # Optional, the value type ("int", "float", "bool" or "str"). Defaults to inference from type of "bounds".
            "log_scale": False,  # Optional, whether to use a log scale for range parameters. Defaults to False.
            # "is_ordered" Optional, a flag for choice parameters.
        },
        {
            "name": "ki",  
            "type": "range",  
            "bounds": [-5.0, 5.0],  
        },
        {
            "name": "kd", 
            "type": "range",
            "bounds": [-3.0, 3.0]
        }
    ],
    objectives={"reward": ObjectiveProperties(minimize=False)},  # The objective name and minimization setting.
    # parameter_constraints: Optional, a list of strings of form "p1 >= p2" or "p1 + p2 <= some_bound".
    # outcome_constraints: Optional, a list of strings of form "constrained_metric <= some_bound".
)
# Out:
# [INFO 06-15 17:11:41] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter ki. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-15 17:11:41] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter kd. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-15 17:11:41] ax.service.utils.instantiation: Created search space: SearchSpace(parameters=[RangeParameter(name='kp', parameter_type=FLOAT, range=[-5.0, 5.0]), RangeParameter(name='ki', parameter_type=FLOAT, range=[-5.0, 5.0]), RangeParameter(name='kd', parameter_type=FLOAT, range=[-3.0, 3.0])], parameter_constraints=[]).
# [INFO 06-15 17:11:41] ax.modelbridge.dispatch_utils: Using Models.GPEI since there are more ordered parameters than there are categories for the unordered categorical parameters.
# [INFO 06-15 17:11:41] ax.modelbridge.dispatch_utils: Calculating the number of remaining initialization trials based on num_initialization_trials=None max_initialization_trials=None num_tunable_parameters=3 num_trials=None use_batch_trials=False
# [INFO 06-15 17:11:41] ax.modelbridge.dispatch_utils: calculated num_initialization_trials=6
# [INFO 06-15 17:11:41] ax.modelbridge.dispatch_utils: num_completed_initialization_trials=0 num_remaining_initialization_trials=6
# [INFO 06-15 17:11:41] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+GPEI', steps=[Sobol for 6 trials, GPEI for subsequent trials]). Iterations after 6 will take longer to generate due to model-fitting.

# %% [markdown]
# # Define how to evaluate the objective

# %%
# Function to compute PID control signal
def compute_pid_control(kp, ki, kd, target, current, prev_error, integral):
    error = target - current
    integral += error
    derivative = error - prev_error
    control_signal = kp * error + ki * integral + kd * derivative
    return control_signal, error, integral
    
# Main function to control the acrobot environment
def control_acrobot(kp, ki, kd, epoch_num=5):
    # Create the acrobot environment
    env = gym.make('Acrobot-v1')
    
    # Control loop
    total_reward_list = []
    for epoch_id in range(epoch_num):
        total_reward = 0
        frames = []
        env.reset()
        # Initialize PID control parameters
        prev_error = 0
        integral = 0    
        for _ in range(500):
            # Get current state
            state = env.state
            # Compute PID control signal for the second joint angle (link1)
            control_signal, prev_error, integral = compute_pid_control(kp, ki, kd, 0, state[0], prev_error, integral)
            # Apply control signal as action
            action = np.array([control_signal])
            # Step the environment
            next_state, reward, done, _ = env.step(max(min(int(control_signal), 2),0))
            # Render the environment
            frames.append(env.render(mode='rgb_array'))
            # env.render()
            # Check if episode is done
            if done:
                break
            total_reward += reward
        total_reward_list.append(total_reward)
    # Close the environment
    env.close()
    
    return np.mean(total_reward_list), frames

# %%
# calculate the reward
def pid_to_reward(pid):
    kp = pid['kp']
    ki = pid['ki']
    kd = pid['kd']
    mean_total_reward, frames = control_acrobot(kp, ki, kd)
    return mean_total_reward

# feed in a set of parameters and visualize the running result
def pid_to_frames(pid):
    kp = pid['kp']
    ki = pid['ki']
    kd = pid['kd']
    mean_total_reward, frames = control_acrobot(kp, ki, kd, epoch_num=1)
    return frames

# %% [markdown]
# # Running the optimization loop

# %%
init_parameters = {
    "kp": 0.1, "ki": 0.1, "kd": 0.1
}

controller_tuner_client.attach_trial(
    parameters=init_parameters
)

# Get the parameters and run the trial 
baseline_parameters = controller_tuner_client.get_trial_parameters(trial_index=0)
controller_tuner_client.complete_trial(trial_index=0, raw_data=pid_to_reward(baseline_parameters))
# Out:
# [INFO 06-15 17:12:10] ax.core.experiment: Attached custom parameterizations [{'kp': 0.1, 'ki': 0.1, 'kd': 0.1}] as trial 0.
# [INFO 06-15 17:12:27] ax.service.ax_client: Completed trial 0 with data: {'reward': (-499.0, None)}.

# %%
# run the optimization loop
for i in range(25):
    parameters, trial_index = controller_tuner_client.get_next_trial()
    # Local evaluation here can be replaced with deployment to external system.
    controller_tuner_client.complete_trial(trial_index=trial_index, raw_data=pid_to_reward(parameters))
# Out:
# [INFO 06-15 17:12:30] ax.service.ax_client: Generated new trial 1 with parameters {'kp': -0.7677, 'ki': 0.783186, 'kd': 0.815372}.
# [INFO 06-15 17:12:42] ax.service.ax_client: Completed trial 1 with data: {'reward': (-499.0, None)}.
# [INFO 06-15 17:12:42] ax.service.ax_client: Generated new trial 2 with parameters {'kp': 2.94442, 'ki': 3.199528, 'kd': -0.683835}.
# [INFO 06-15 17:13:03] ax.service.ax_client: Completed trial 2 with data: {'reward': (-499.0, None)}.
# [INFO 06-15 17:13:03] ax.service.ax_client: Generated new trial 3 with parameters {'kp': 1.091582, 'ki': -2.409644, 'kd': 0.904219}.
# [INFO 06-15 17:13:10] ax.service.ax_client: Completed trial 3 with data: {'reward': (-94.0, None)}.
# [INFO 06-15 17:13:10] ax.service.ax_client: Generated new trial 4 with parameters {'kp': 2.466528, 'ki': 2.451341, 'kd': 0.637285}.
# [INFO 06-15 17:13:27] ax.service.ax_client: Completed trial 4 with data: {'reward': (-499.0, None)}.
# [INFO 06-15 17:13:27] ax.service.ax_client: Generated new trial 5 with parameters {'kp': -1.695505, 'ki': 2.134968, 'kd': -1.457427}.
# [INFO 06-15 17:13:43] ax.service.ax_client: Completed trial 5 with data: {'reward': (-499.0, None)}.
# [INFO 06-15 17:13:43] ax.service.ax_client: Generated new trial 6 with parameters {'kp': 2.933587, 'ki': 0.97006, 'kd': 1.985467}.
# [INFO 06-15 17:14:00] ax.service.ax_client: Completed trial 6 with data: {'reward': (-499.0, None)}.
# [INFO 06-15 17:14:03] ax.service.ax_client: Generated new trial 7 with parameters {'kp': 1.209756, 'ki': -3.541288, 'kd': 1.144703}.
# [INFO 06-15 17:14:06] ax.service.ax_client: Completed trial 7 with data: {'reward': (-98.6, None)}.
# [INFO 06-15 17:14:11] ax.service.ax_client: Generated new trial 8 with parameters {'kp': -0.384002, 'ki': -3.000404, 'kd': 2.108074}.
# [INFO 06-15 17:14:14] ax.service.ax_client: Completed trial 8 with data: {'reward': (-91.6, None)}.
# [INFO 06-15 17:14:17] ax.service.ax_client: Generated new trial 9 with parameters {'kp': 2.394361, 'ki': -2.913168, 'kd': 2.406447}.
# [INFO 06-15 17:14:20] ax.service.ax_client: Completed trial 9 with data: {'reward': (-97.8, None)}.
# [INFO 06-15 17:14:25] ax.service.ax_client: Generated new trial 10 with parameters {'kp': -1.331185, 'ki': -3.17251, 'kd': -0.034366}.
# [INFO 06-15 17:14:29] ax.service.ax_client: Completed trial 10 with data: {'reward': (-121.6, None)}.
# [INFO 06-15 17:14:37] ax.service.ax_client: Generated new trial 11 with parameters {'kp': 1.140636, 'ki': -2.921879, 'kd': 1.196715}.
# [INFO 06-15 17:14:40] ax.service.ax_client: Completed trial 11 with data: {'reward': (-81.2, None)}.
# [INFO 06-15 17:14:47] ax.service.ax_client: Generated new trial 12 with parameters {'kp': 4.945503, 'ki': -3.15564, 'kd': -0.421004}.
# [INFO 06-15 17:14:51] ax.service.ax_client: Completed trial 12 with data: {'reward': (-99.8, None)}.
# [INFO 06-15 17:14:58] ax.service.ax_client: Generated new trial 13 with parameters {'kp': 2.964131, 'ki': -2.872717, 'kd': 0.624702}.
# [INFO 06-15 17:15:04] ax.service.ax_client: Completed trial 13 with data: {'reward': (-144.2, None)}.
# [INFO 06-15 17:15:07] ax.service.ax_client: Generated new trial 14 with parameters {'kp': 4.953702, 'ki': -4.441625, 'kd': -1.719551}.
# [INFO 06-15 17:15:11] ax.service.ax_client: Completed trial 14 with data: {'reward': (-104.0, None)}.
# [INFO 06-15 17:15:16] ax.service.ax_client: Generated new trial 15 with parameters {'kp': 5.0, 'ki': -4.90649, 'kd': 1.653463}.
# [INFO 06-15 17:15:21] ax.service.ax_client: Completed trial 15 with data: {'reward': (-103.0, None)}.
# [INFO 06-15 17:15:30] ax.service.ax_client: Generated new trial 16 with parameters {'kp': -0.789824, 'ki': -5.0, 'kd': 3.0}.
# [INFO 06-15 17:15:35] ax.service.ax_client: Completed trial 16 with data: {'reward': (-91.2, None)}.
# [INFO 06-15 17:15:40] ax.service.ax_client: Generated new trial 17 with parameters {'kp': -5.0, 'ki': -4.071924, 'kd': 3.0}.
# [INFO 06-15 17:15:43] ax.service.ax_client: Completed trial 17 with data: {'reward': (-101.6, None)}.
# [INFO 06-15 17:15:48] ax.service.ax_client: Generated new trial 18 with parameters {'kp': -2.748103, 'ki': -5.0, 'kd': 0.076769}.
# [INFO 06-15 17:15:52] ax.service.ax_client: Completed trial 18 with data: {'reward': (-108.8, None)}.
# [INFO 06-15 17:15:56] ax.service.ax_client: Generated new trial 19 with parameters {'kp': -0.420262, 'ki': -3.875973, 'kd': 3.0}.
# [INFO 06-15 17:16:00] ax.service.ax_client: Completed trial 19 with data: {'reward': (-94.8, None)}.
# [INFO 06-15 17:16:04] ax.service.ax_client: Generated new trial 20 with parameters {'kp': 0.279582, 'ki': -5.0, 'kd': -3.0}.
# [INFO 06-15 17:16:10] ax.service.ax_client: Completed trial 20 with data: {'reward': (-194.2, None)}.
# [INFO 06-15 17:16:17] ax.service.ax_client: Generated new trial 21 with parameters {'kp': -5.0, 'ki': -5.0, 'kd': 2.394722}.
# [INFO 06-15 17:16:21] ax.service.ax_client: Completed trial 21 with data: {'reward': (-99.4, None)}.
# [INFO 06-15 17:16:26] ax.service.ax_client: Generated new trial 22 with parameters {'kp': 1.285246, 'ki': -5.0, 'kd': 0.896228}.
# [INFO 06-15 17:16:29] ax.service.ax_client: Completed trial 22 with data: {'reward': (-109.2, None)}.
# [INFO 06-15 17:16:36] ax.service.ax_client: Generated new trial 23 with parameters {'kp': 5.0, 'ki': -3.920711, 'kd': 3.0}.
# [INFO 06-15 17:16:39] ax.service.ax_client: Completed trial 23 with data: {'reward': (-85.6, None)}.
# [INFO 06-15 17:16:46] ax.service.ax_client: Generated new trial 24 with parameters {'kp': 5.0, 'ki': -4.035382, 'kd': 0.765151}.
# [INFO 06-15 17:16:50] ax.service.ax_client: Completed trial 24 with data: {'reward': (-104.8, None)}.
# [INFO 06-15 17:16:54] ax.service.ax_client: Generated new trial 25 with parameters {'kp': -2.304171, 'ki': -4.071683, 'kd': 1.791798}.
# [INFO 06-15 17:16:58] ax.service.ax_client: Completed trial 25 with data: {'reward': (-111.2, None)}.

# %%
best_parameters, _ = controller_tuner_client.get_best_parameters()
print(best_parameters)
# Out:
# {'kp': -0.4202620826307344, 'ki': -3.8759728102837663, 'kd': 3.0}

# %% [markdown]
# # Visualize the improvement

# %%
plt.plot(controller_tuner_client.get_optimization_trace()[0]['data'][0]['x'], controller_tuner_client.get_optimization_trace()[0]['data'][0]['y'])

# %%
init_frames = pid_to_frames(init_parameters) 
show_video(init_frames)
# Out:
# Moviepy - Building video ./render_videos/tmp.mp4.
# Moviepy - Writing video ./render_videos/tmp.mp4
# Moviepy - Done !
# Moviepy - video ready ./render_videos/tmp.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
best_frames = pid_to_frames(best_parameters)
show_video(best_frames)
# Out:
# Moviepy - Building video ./render_videos/tmp.mp4.
# Moviepy - Writing video ./render_videos/tmp.mp4
# Moviepy - Done !
# Moviepy - video ready ./render_videos/tmp.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
